# %% [markdown]
# <a href="https://colab.research.google.com/github/harshi2709/Internship/blob/master/Scientific_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
from skimage import data

# %%
matplotlib.rcParams['font.size'] = 18

# %%
images = ('hubble_deep_field',
          'immunohistochemistry',
          'microaneurysms',
          'moon',
          'retina',
          )

# %%
for name in images:
    caller = getattr(data, name)
    image = caller()
    plt.figure()
    plt.title(name)
    if image.ndim == 2:
        plt.imshow(image, cmap=plt.cm.gray)
    else:
      plt.imshow(image)
      
plt.show()

# %%
plt.dra()
