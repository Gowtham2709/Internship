# %% [markdown]
# <a href="https://colab.research.google.com/github/harshi2709/Internship/blob/master/Web_scraping/newsapi/program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = ('https://newsapi.org/v2/top-headlines?'
       'country=in&'
       'apiKey=8c88415e1c794bc487b31bbadb4ec25e')
response = requests.get(url)
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 38, 'articles': [{'source': {'id': None, 'name': 'Firstpost.com'}, 'author': None, 'title': "P Chidambaram Hearing in Supreme Court LIVE updates: Kapil Sibal accuses ED of leaking counter-affidavit to media, calls case 'media trial' - Firstpost", 'description': "P Chidambaram Hearing in Supreme Court LIVE updates: After dismissing former finance minister P Chidambaram's plea against the denial of bail in the INX Media case, the Supreme Court also heard the Congress leader's petition against the Enforcement Directorat…", 'url': 'https://www.firstpost.com/india/chidambaram-hearing-in-supreme-court-live-updates-latest-news-p-chidambaram-case-cbi-arrest-inx-media-property-bail-plea-kapil-sibal-congress-karti-chidambaram-7225851.html', 'urlToImage': 'https://images.firstpost.com/wp-content/uploads/2019/08/Chidamabaram_1280_PTI.jpg', 'publishedAt': '2019-08-26T07:42:09Z', 'content': None}, {'source': {'id': 'the-times-of-india', 'name': 'The Times of India'
# ...

# %%
import requests
url = ('https://newsapi.org/v2/top-headlines?'
       'sources=google-news-in&'
       'apiKey=8c88415e1c794bc487b31bbadb4ec25e')
response = requests.get(url)
print (response.json())
# Out:
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'google-news-in', 'name': 'Google News (India)'}, 'author': None, 'title': 'Setback For P Chidambaram, Top Court Says His Petition "Infructuous"', 'description': 'Former Finance Minister P Chidambaram, arrested on Wednesday in a corruption investigation, suffered a series of setbacks in the Supreme Court today. His petition challenging his CBI custody was not listed for a hearing at the top court. A bench told Mr Chida…', 'url': 'https://www.ndtv.com/india-news/will-p-chidambaram-get-bail-today-supreme-court-to-decide-10-points-2090343', 'urlToImage': 'https://c.ndtvimg.com/2019-08/c24smdvg_p-chidambaram-pti-cbi-court_625x300_22_August_19.jpg', 'publishedAt': '2019-08-26T06:59:00+00:00', 'content': '<ol><li>"I have a right to be heard," Mr Sibal said on behalf of Mr Chidambaram, referring to the team\'s failed attempts to get a Supreme Court hearing on the former minister\'s request for pre-arrest bail on Tuesday and
# ...

# %%
import requests
url = ('https://newsapi.org/v2/top-headlines?'
       'sources=mtv-news&'
       'apiKey=8c88415e1c794bc487b31bbadb4ec25e')
response = requests.get(url)
print (response.json())
# Out:
# {'status': 'ok', 'totalResults': 5, 'articles': [{'source': {'id': 'mtv-news', 'name': 'MTV News'}, 'author': 'Jordyn Tilchen', 'title': "Which Song From Taylor Swift's Lover Should You Listen To Based On Your Mood?", 'description': 'We broke down her new album to its essential, emotional parts', 'url': 'http://www.mtv.com/news/3136336/taylor-swift-lover-album-song-mood/', 'urlToImage': 'https://mtv.mtvnimages.com/uri/mgid:ao:image:mtv.com:680570?quality=0.8&format=jpg&width=1440&height=810&.jpg', 'publishedAt': '2019-08-24T13:18:44Z', 'content': "The day finally came, Swifties. Taylor Swift's seventh studio album, Lover, dropped on Friday (August 23), and it's everything fans could've hoped for. The 18-track LP, which spans roughly one hour from start to finish, perfectly encapsulates love in all its … [+10582 chars]"}, {'source': {'id': 'mtv-news', 'name': 'MTV News'}, 'author': 'Alissa Schulman', 'title': 'Lizzie McGuire Is Returning To Ease Millennials Into Their Thirties', 'desc
# ...

# %%
import requests
url = ('https://newsapi.org/v2/everything?'
       'sources=mtv-news&'
       'apiKey=8c88415e1c794bc487b31bbadb4ec25e')
response = requests.get(url)
print (response.json())
# Out:
# {'status': 'ok', 'totalResults': 337, 'articles': [{'source': {'id': 'mtv-news', 'name': 'MTV News'}, 'author': 'Alissa Schulman', 'title': 'New Star Wars: The Rise Of Skywalker Footage Teases Rey’s Dark Side', 'description': "'Star Wars: The Rise of Skywalker' debuted a new trailer at D23, plus director J.J. Abrams recalled memories of the late Carrie Fisher and Keri Russell revealed more about her new character, Zorii Bliss.", 'url': 'http://www.mtv.com/news/3136567/star-wars-the-rise-of-skywalker-d23-footage/', 'urlToImage': 'https://mtv.mtvnimages.com/uri/mgid:ao:image:mtv.com:680634?quality=0.8&format=jpg&width=1440&height=810&.jpg', 'publishedAt': '2019-08-24T23:22:40Z', 'content': "One day after the trailer for Disney+'s The Mandalorian dropped, which will add to the storied Star Wars universe this coming November, Lucasfilm president Kathleen Kennedy returned to D23 to share even more news about the upcoming conclusion to the Skywalker… [+2376 chars]"}, {'source': {'id': 'mtv
# ...
